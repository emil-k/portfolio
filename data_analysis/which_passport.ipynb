# %% [markdown]
# ### As a dual citizen, I am curious which passport I should best use entering what country.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
import numpy as np

# %%
german = "https://en.wikipedia.org/wiki/Visa_requirements_for_German_citizens"
polish = "https://en.wikipedia.org/wiki/Visa_requirements_for_Polish_citizens"

de_html = requests.get(german).text
pl_html = requests.get(polish).text

# %%
de_soup = BeautifulSoup(de_html, 'lxml')
de = pd.read_html(str(de_soup.find("table", {'class' : 'sortable wikitable'})), skiprows=1)[0]

pl_soup = BeautifulSoup(pl_html, 'lxml')
pl = pd.read_html(str(pl_soup.find("table", {'class' : 'sortable wikitable'})), skiprows=1)[0]

# %%
de.head()
# Out:
#              0                      1        2  \
# 0  Afghanistan      Visa required[32]      NaN
# 1      Albania  Visa not required[33]  90 days
# 2      Algeria      Visa required[34]      NaN
# 3      Andorra  Visa not required[35]      NaN
# 4       Angola          eVisa[36][37]  30 days
#
#                                                    3
# 0                                                NaN
# 1                                      ID card valid
# 2                                                NaN
# 3                                      ID card valid
# 4  Visitors who have been granted an online pre-v...

# %%
pl.head()
# Out:
#              0                     1        2  \
# 0  Afghanistan      Visa required[2]      NaN
# 1      Albania  Visa not required[3]  90 days
# 2      Algeria      Visa required[4]      NaN
# 3      Andorra  Visa not required[5]      NaN
# 4       Angola           eVisa[6][7]  30 days
#
#                                                    3
# 0                                                NaN
# 1                                      ID card valid
# 2                                                NaN
# 3                                      ID card valid
# 4  Visitors who have been granted an online pre-v...

# %%
# I am going to merge them into one dataframe to avoid running every function twice on each data frame
# and then separate them when I'm done

# %%
de.columns = ['country', 'status', 'duration', 'notes']
pl.columns = ['country', 'status', 'duration', 'notes']

de['cat'] = 'DE'
pl['cat'] = 'PL'

df = de.append(pl)

# %%
de.status.str.contains("\[").value_counts()
# Out:
# True    193
# Name: status, dtype: int64

# %%
df.status = df.status.str.findall("^(.+?)\[").apply(lambda x: x[0] if len(x) > 0 else np.nan)

# %%
df.status.value_counts()
# Out:
# Visa not required                  230
# Visa required                       56
# eVisa / Visa on arrival             40
# Visa on arrival                     28
# eVisa                               20
# eVisitor                             2
# Tourist Card required                2
# Electronic Travel Authority          2
# Visa Waiver Program                  2
# Electronic Travel Authorization      1
# Free visa on arrival                 1
# E-tourist card                       1
# eVisa / Free visa on arrival         1
# Name: status, dtype: int64

# %%
d = {'eVisa / Visa on arrival' : 'eVisa',
    'Visa Waiver Program' : 'Visa not required',
    'Tourist Card required' : 'Visa required',
    'Tourist Card on arrival' : 'Visa on arrival',
    'eVisitor' : 'eVisa',
    'Free visa on arrival' : 'Visa on arrival'}

# %%
df.status.replace(d, inplace=True)

# %%
df.head()
# Out:
#        country             status duration  \
# 0  Afghanistan      Visa required      NaN
# 1      Albania  Visa not required  90 days
# 2      Algeria      Visa required      NaN
# 3      Andorra  Visa not required      NaN
# 4       Angola              eVisa  30 days
#
#                                                notes cat
# 0                                                NaN  DE
# 1                                      ID card valid  DE
# 2                                                NaN  DE
# 3                                      ID card valid  DE
# 4  Visitors who have been granted an online pre-v...  DE

# %%
df.notes.fillna('missing', inplace=True)

# %%
df[df.notes.str.contains('[0-9]')].head()
# Out:
#                    country             status  duration  \
# 4                   Angola              eVisa        30
# 8                Australia              eVisa        90
# 15                 Belarus  Visa not required        30
# 21  Bosnia and Herzegovina  Visa not required        90
# 23                  Brazil  Visa not required        90
#
#                                                 notes cat
# 4   Visitors who have been granted an online pre-v...  DE
# 8   90 days on each visit in 12-month period if gr...  DE
# 15  Must arrive and depart via Minsk International...  DE
# 21    90 days within any 6-month period ID card valid  DE
# 23                  90 days within any 180 day period  DE

# %%
mask = df.duration.isnull()
mask2 = df.notes.str.contains('[0-9]')

df[mask * mask2]
# Out:
#       country                           status duration  \
# 35      China                    Visa required      NaN
# 80     Israel                Visa not required      NaN
# 84     Jordan                  Visa on arrival      NaN
# 130  Pakistan  Electronic Travel Authorization      NaN
# 141    Russia                    Visa required      NaN
# 158   Somalia                  Visa on arrival      NaN
# 179    Uganda                            eVisa      NaN
# 35      China                    Visa required      NaN
# 85     Jordan                  Visa on arrival      NaN
# 131  Pakistan                            eVisa      NaN
# 141    Russia                    Visa required      NaN
# 158   Somalia                  Visa on arrival      NaN
# 179    Uganda                            eVisa      NaN
#
#                                                  notes cat
# 35   72-hour visit without a visa when in transit a...  DE
# 80   3 months for tourism only.[131] German citizen...  DE
# 84                               Conditions apply[136]  DE
# 130  Electronic Travel Authorization to obtain a vi...  DE
# 141  Free-of-charge eVisa is required for visits of...  DE
# 158  Available at Berbera, Borama, Burao, Erigavo a...  DE
# 179                             May apply online.[248]  DE
# 35   72-hour visit without a visa when in transit a...  PL
# 85   Conditions apply.[109] Not available at all en...  PL
# 131  Online Visa eligible.[163] Electronic Travel A...  PL
# 141  From 1 July 2019, Polish citizens are eligible...  PL
# 158  Available at Berbera, Borama, Burao, Erigavo a...  PL
# 179  Determined at the port of entry. May apply onl...  PL

# %%
df.iloc[80]['duration'] = '90'

# %%
df.duration.fillna("0", inplace=True)

# %%
df.loc[df.duration.str.contains("month"), 'duration']
# Out:
# 5          6 months
# 11         8 months
# 14         6 months
# 17          1 month
# 26          1 month
# 30         6 months
# 41         3 months
# 52         3 months
# 58         4 months
# 66         3 months
# 70         3 months
# 72         3 months
# 86         3 months
# 90         3 months
# 94          1 month
# 103        3 months
# 119        3 months
# 123        3 months
# 143        3 months
# 152        3 months
# 169        3 months
# 175        4 months
# 176        3 months
# 192        3 months
# 5      6 months[11]
# 11         3 months
# 14         3 months
# 17          1 month
# 26          1 month
# 30         6 months
# 41         3 months
# 52         3 months
# 58         4 months
# 67         3 months
# 73         3 months
# 81         3 months
# 87         3 months
# 91         3 months
# 95          1 month
# 104        3 months
# 120        3 months
# 143        3 months
# 152        3 months
# 169        3 months
# 175        3 months
# 176        3 months
# 192        3 months
# Name: duration, dtype: object

# %%
# Converting months to days

df.loc[df.duration.str.contains("month"), 'duration'] = \
df.loc[df.duration.str.contains("month"), 'duration'].str.findall("([0-9])").apply(lambda x : str(int(x[0]) * 30))

# %%
df.loc[df.duration.str.contains("days"), 'duration'] = \
df.loc[df.duration.str.contains("days"), 'duration'].str.findall("([0-9]+)\sdays").apply(lambda x: x[0])

# %%
df.loc[df.duration.str.contains("Freedom of movement"), 'duration'] = '999'

# %%
df[df.duration.str.contains("[^0-9]")]
# Out:
#     country             status duration          notes cat
# 63  Georgia  Visa not required   1 year  ID card valid  DE
# 37  Comoros    Visa on arrival  2 weeks        missing  PL
# 63  Georgia  Visa not required   1 year  ID card valid  PL

# %%
df.replace("1 year", "365", inplace=True)
df.replace("2 weeks", "14", inplace=True)

# %%
df.duration = df.duration.astype(int)

# %%
pl = df[df.cat == "PL"]
de = df[df.cat == "DE"]

# %%
len(de) == len(pl)
# Out:
# True

# %%
merged = pd.merge(pl, df, on="country", suffixes=('_PL', '_DE'))

# %% [markdown]
# ### Longer stay on German passport

# %%
merged[merged.duration_DE > merged.duration_PL]
# Out:
#           country          status_PL  duration_PL notes_PL cat_PL  \
# 22        Bahamas  Visa not required           90  missing     PL
# 28       Barbados  Visa not required           90  missing     PL
# 141        Guyana      Visa required            0  missing     PL
# 165       Jamaica  Visa not required           30  missing     PL
# 191       Lesotho              eVisa            0  missing     PL
# 229      Mongolia      Visa required            0  missing     PL
# 317  South Africa  Visa not required           30  missing     PL
# 327      Suriname              eVisa            0  missing     PL
# 349       Tunisia  Visa not required           90  missing     PL
#
#              status_DE  duration_DE  \
# 22   Visa not required          240
# 28   Visa not required          180
# 141  Visa not required           90
# 165  Visa not required           90
# 191  Visa not required           14
# 229  Visa not required           30
# 317  Visa not required           90
# 327     E-tourist card           90
# 349  Visa not required          120
#
#                                          notes_DE cat_DE
# 22                                        missing     DE
# 28                                        missing     DE
# 141                                       missing     DE
# 165                                       missing     DE
# 191                                       missing     DE
# 229                                       missing     DE
# 317                                       missing     DE
# 327  Multiple entry eVisa is also available.[230]     DE
# 349                ID card valid in certain cases     DE

# %% [markdown]
# ### Longer stay on Polish passport

# %%
merged[merged.duration_DE < merged.duration_PL]
# Out:
#      country        status_PL  duration_PL  \
# 74   Comoros  Visa on arrival           14
# 151    India            eVisa          180
# 205   Malawi            eVisa           90
# 377  Vietnam            eVisa           30
#
#                                               notes_PL cat_PL  \
# 74                                             missing     PL
# 151  e-Visa holders must arrive via 26 designated a...     PL
# 205                                            missing     PL
# 377                                            missing     PL
#
#              status_DE  duration_DE  \
# 74     Visa on arrival            0
# 151              eVisa           60
# 205              eVisa            0
# 377  Visa not required           15
#
#                                               notes_DE cat_DE
# 74                                             missing     DE
# 151  e-Visa holders must arrive via 26 designated a...     DE
# 205                                            missing     DE
# 377  A single entry eVisa valid for 30 days is also...     DE

# %% [markdown]
# ### Visa not required on German passport

# %%
mask1 = merged.status_DE.str.contains("not required")
mask2 = merged.status_PL.str.contains("not required")

merged[mask1 * ~mask2]
# Out:
#       country        status_PL  duration_PL  \
# 141    Guyana    Visa required            0
# 191   Lesotho            eVisa            0
# 229  Mongolia    Visa required            0
# 239   Namibia  Visa on arrival           90
# 351    Turkey            eVisa           90
# 377   Vietnam            eVisa           30
#
#                                              notes_PL cat_PL  \
# 141                                           missing     PL
# 191                                           missing     PL
# 229                                           missing     PL
# 239  Available at Hosea Kutako International Airport.     PL
# 351                                           missing     PL
# 377                                           missing     PL
#
#              status_DE  duration_DE  \
# 141  Visa not required           90
# 191  Visa not required           14
# 229  Visa not required           30
# 239  Visa not required           90
# 351  Visa not required           90
# 377  Visa not required           15
#
#                                               notes_DE cat_DE
# 141                                            missing     DE
# 191                                            missing     DE
# 229                                            missing     DE
# 239                    3 months within a calendar year     DE
# 351  ID card valid[243] Former Turkish citizens wit...     DE
# 377  A single entry eVisa valid for 30 days is also...     DE

# %% [markdown]
# ### Visa not required on Polish passport

# %%
merged[~mask1 * mask2]
# Out:
# Empty DataFrame
# Columns: [country, status_PL, duration_PL, notes_PL, cat_PL, status_DE, duration_DE, notes_DE, cat_DE]
# Index: []
